# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/cals.csv')
df['CDiff'] = df.CIn - df.COut
df.head()
# Out:
#         Date     Wt    Steps    COut     CIn   CDiff
# 0  5/12/2018  192.5  23938.0  3620.0  1417.0 -2203.0
# 1  5/13/2018  192.7  25926.0  3737.0  1761.0 -1976.0
# 2  5/14/2018  190.5  23516.0  3561.0  1922.0 -1639.0
# 3  5/15/2018  189.7  19930.0  3287.0  1386.0 -1901.0
# 4  5/16/2018  188.5  13317.0  2833.0  2087.0  -746.0

# %%
df.hist(column="Steps")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B930ED4D30>]],
#       dtype=object)

# %%
df.plot(x="Date", y="Wt")

# %%
df[-30:].plot(x="Date", y="Wt")

# %%
df.plot(x="Date", y="Steps")

# %%
df[['Date','CIn', 'COut']].plot(x="Date")

# %%
df.plot(x="Date", y="CDiff")
